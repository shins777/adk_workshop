# %%
# Copyright 2025 Forusone
#
# Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
#     https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# ### This notebook is a common library for installing and authentication.

# %%
#@title Install google-cloud-aiplatform
# %pip install --upgrade --user --quiet google-cloud-aiplatform[agent_engines,adk,langchain,ag2,llama_index]
print("1. google-cloud-aiplatform installed")

# %%
#@title Install google-genai
# %pip install --upgrade --user --quiet google-genai
print("2. google-genai installed ")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.7/159.7 kB 6.9 MB/s eta 0:00:00

# %%
#@title Install langchain-google-vertexai
# %pip install --upgrade --user --quiet langchain-google-vertexai
print("3. langchain-google-vertexai installed ")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 1.3 MB/s eta 0:00:00

# %%
# @title Authentication to access to GCP

# To use markdown for output data from LLM
from IPython.display import display, Markdown

# @title Define constants
PROJECT_ID = "ai-hangsik"
LOCATION = "us-central1"
MODEL_NAME = "gemini-2.0-flash"
BUCKET_URI = f"gs://agent-0417"

print(f"3. Project Information \n\t{PROJECT_ID}\n\t{LOCATION}\n\t{MODEL_NAME}\n\t{BUCKET_URI}")

# Use OAuth to access the GCP environment.
import sys
if "google.colab" in sys.modules:
    from google.colab import auth
    auth.authenticate_user(project_id = PROJECT_ID)

print("4. authentication passed ")

# %%
# @title Create a bucket.
! gsutil mb -l {LOCATION} -p {PROJECT_ID} {BUCKET_URI}
print(f"5. Bucket created")

# %%
# @title Initialize Vertex AI with Staging Bucket.

import vertexai

vertexai.init(project=PROJECT_ID, location=LOCATION, staging_bucket=BUCKET_URI)
print(f"6. Vertex AI initialized")

# %% [markdown]
# ## End of Notebook
